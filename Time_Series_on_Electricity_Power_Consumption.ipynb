# %% [markdown]
# # **Time Series on Electricity Power Consumption**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/household_power_consumption.txt',sep=';')

# %%
df
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# 2075257  26/11/2010  21:01:00               0.934                   0.0
# 2075258  26/11/2010  21:02:00               0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# 0        234.840           18.400          0.000          1.000
# 1        233.630           23.000          0.000          1.000
# 2        233.290           23.000          0.000          2.000
# 3        233.740           23.000          0.000          1.000
# 4        235.680           15.800          0.000          1.000
# ...          ...              ...            ...            ...
# 2075254   240.43              4.0            0.0            0.0
# 2075255    240.0              4.0            0.0            0.0
# 2075256   239.82              3.8            0.0            0.0
# 2075257    239.7              3.8            0.0            0.0
# 2075258   239.55              3.8            0.0            0.0
#
#          Sub_metering_3
# 0                  17.0
# 1                  16.0
# 2                  17.0
# 3                  17.0
# 4                  17.0
# ...                 ...
# 2075254             0.0
# 2075255             0.0
# 2075256             0.0
# 2075257             0.0
# 2075258             0.0
#
# [2075259 rows x 9 columns]

# %%
# First 5 rows of dataset
df.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
# Last 5 rows of dataset
df.tail()
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# 2075257  26/11/2010  21:01:00               0.934                   0.0
# 2075258  26/11/2010  21:02:00               0.932                   0.0
#
#         Voltage Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 2075254  240.43              4.0            0.0            0.0             0.0
# 2075255   240.0              4.0            0.0            0.0             0.0
# 2075256  239.82              3.8            0.0            0.0             0.0
# 2075257   239.7              3.8            0.0            0.0             0.0
# 2075258  239.55              3.8            0.0            0.0             0.0

# %%
df.shape
# Out:
# (2075259, 9)

# %%
print('Columns of dataset are:\n')
for i,col in enumerate(df.columns.tolist()):
  print(i+1,'-',col)
# Out:
# Columns of dataset are:
#
# 1 - Date
# 2 - Time
# 3 - Global_active_power
# 4 - Global_reactive_power
# 5 - Voltage
# 6 - Global_intensity
# 7 - Sub_metering_1
# 8 - Sub_metering_2
# 9 - Sub_metering_3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Global_active_power    object
#  3   Global_reactive_power  object
#  4   Voltage                object
#  5   Global_intensity       object
#  6   Sub_metering_1         object
#  7   Sub_metering_2         object
#  8   Sub_metering_3         float64
# dtypes: float64(1), object(8)
# memory usage: 142.5+ MB

# %%
df1 = df[["Date","Time","Global_active_power"]]

# %%
# Combine and convert to datetime
df1['Datetime'] = pd.to_datetime(df1['Date'] + ' ' + df1['Time'], dayfirst=True)
df1.set_index('Datetime', inplace=True)
df1.drop(columns=['Date', 'Time'], inplace=True)

# %%
df1["Global_active_power"] = pd.to_numeric(df1["Global_active_power"],errors='coerce')

# %% [markdown]
# ## Handle Missing Values

# %%
df1.isnull().sum()
# Out:
# Global_active_power    25979
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                         0
# Time                         0
# Global_active_power          0
# Global_reactive_power        0
# Voltage                      0
# Global_intensity             0
# Sub_metering_1               0
# Sub_metering_2               0
# Sub_metering_3           25979
# dtype: int64

# %%
print(f'Percentage of Missing values in the Dataset : {round((df.isnull().sum()[-1]*100/df.shape[0]),2)} %')
# Out:
# Percentage of Missing values in the Dataset : 1.25 %

# %%
import missingno as mn
mn.matrix(df1)
plt.show()

# %%
mn.matrix(df)
plt.show()

# %%
df1.dropna(inplace=True)

# %% [markdown]
# # Resampling to Weekly **Data**

# %%
df_weekly = df1.resample('W').sum()

# %%
df_weekly.head()
# Out:
#             Global_active_power
# Datetime
# 2006-12-17             4599.636
# 2006-12-24            17477.128
# 2006-12-31            19736.518
# 2007-01-07            14961.068
# 2007-01-14            16176.334

# %%
df_weekly.isnull().sum()
# Out:
# Global_active_power    0
# dtype: int64

# %%
df_weekly.columns=["EC"]
df_weekly.shape
# Out:
# (207, 1)

# %%
fig, ax = plt.subplots(figsize=(12,5))
ax.plot(df_weekly.index,df_weekly["EC"],color="blue",label="Initial plot")
ax.set_xlabel('Time')
ax.set_ylabel("Electricity Consumption")
ax.set_title("Electricity Consumption over time")
plt.grid(True)
plt.show()

# %%
# Decompose the series
from statsmodels.tsa.seasonal import STL , seasonal_decompose
result = seasonal_decompose(df_weekly['EC'], model='additive', period=52)

# Custom large plots
fig, axes = plt.subplots(4, 1, figsize=(25, 20), sharex=True)

# Plot observed
axes[0].plot(result.observed, color='green')
axes[0].set_ylabel("Observed")
axes[0].set_title("Time Series Decomposition of Global_active_power", fontsize=16)

# Plot trend
axes[1].plot(result.trend, color='red')
axes[1].set_ylabel("Trend")

# Plot seasonal
axes[2].plot(result.seasonal, color='black')
axes[2].set_ylabel("Seasonality")

# Plot residual
axes[3].plot(result.resid, color='blue')
axes[3].set_ylabel("Residuals")
axes[3].set_xlabel("Date")

plt.tight_layout()
plt.show()

# %%
import plotly.express as px

# Perform Fourier Transform
fft_vals = np.fft.fft(df_weekly['EC'])
fft_freqs = np.fft.fftfreq(len(df_weekly))

# Only keep the positive frequencies
positive_freqs = fft_freqs[fft_freqs >= 0]
positive_vals = np.abs(fft_vals[fft_freqs >= 0])

fig = px.line(y= positive_vals, x=positive_freqs, title='Periodogram')
fig.update_layout(
    xaxis_title='Frequency',
    yaxis_title='Amplitude'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6f6fb553-ee41-401a-bac7-634540b493ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f6fb553-ee41-401a-bac7-634540b493ca")) {                    Plotly.newPlot(                        "6f6fb553-ee41-401a-bac7-634540b493ca",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[0.0,0.004830917874396135,0.00966183574879227,0.014492753623188404,0.01932367149758454,0.024154589371980676,0.02898550724637681,0.033816425120772944,0.03864734299516908,0.043478260869565216,0.04830917874396135,0.05314009661835749,0.05797101449275362,0.06280193236714976,0.06763285024154589,0.07246376811594203,0.07729468599033816,0.08212560386473429,0.08695652173913043,0.09178743961352656,0.0966183574879227,0.10144927536231883,0.10628019323671498,0.1111111111111111,0.11594202898550723,0.12077294685990338,0.12560386473429952,0.13043478260869565,0.13526570048309178,0.1400966183574879,0.14492753623188406,0.1497584541062802,0.15458937198067632,0.15942028985507245,0.16425120772946858,0.16908212560386474,0.17391304347826086,0.178743961352657,0.18357487922705312,0.18840579710144928,0.1932367149758454,0.19806763285024154,0.20289855072463767,0.2077294685990338,0.21256038647342995,0.21739130434782608,0.2222222222222222,0.22705314009661834,0.23188405797101447,0.23671497584541062,0.24154589371980675,0.24637681159420288,0.25120772946859904,0.25603864734299514,0.2608695652173913,0.26570048309178745,0.27053140096618356,0.2753623188405797,0.2801932367149758,0.28502415458937197,0.2898550724637681,0.2946859903381642,0.2995169082125604,0.3043478260869565,0.30917874396135264,0.3140096618357488,0.3188405797101449,0.32367149758454106,0.32850241545893716,0.3333333333333333,0.33816425120772947,0.3429951690821256,0.34782608695652173,0.35265700483091783,0.357487922705314,0.36231884057971014,0.36714975845410625,0.3719806763285024,0.37681159420289856,0.38164251207729466,0.3864734299516908,0.3913043478260869,0.3961352657004831,0.40096618357487923,0.40579710144927533,0.4106280193236715,0.4154589371980676,0.42028985507246375,0.4251207729468599,0.429951690821256,0.43478260869565216,0.43961352657004826,0.4444444444444444,0.4492753623188406,0.4541062801932367,0.45893719806763283,0.46376811594202894,0.4685990338164251,0.47342995169082125,0.47826086956521735,0.4830917874396135,0.48792270531400966,0.49275362318840576,0.4975845410628019],"xaxis":"x","y":[2237024.8619999997,20748.518508458714,27110.39365303195,22604.323854987626,366725.25504317635,25318.850062974627,56142.75050073188,34344.53056155282,90601.29823027471,59996.189374167516,36612.81777590265,9356.465167879165,78166.54633428664,38060.983726326864,49837.53926483009,23216.289571195168,54005.99520416711,29118.05177676314,32319.249008456492,47055.05084270062,20787.315152395786,57901.41131464849,31587.036149287193,55346.34603252526,61495.72254403727,18985.39640676008,44228.94087029688,26353.629350173247,45014.59050633172,37052.93729134044,40649.08637623063,30393.849137088422,36189.61318652884,30635.583199712608,25309.003077630718,24741.898751150577,43092.40328100323,36013.55609872351,38369.43194382766,6266.471744136634,60474.83124598324,27824.24755515498,21588.856913324813,8584.157011512734,20320.008339691867,21514.671557799535,26872.25070666109,18788.308418797467,28004.587151752126,30418.60745385285,16345.650677669319,10857.071027857573,35061.35263310105,24209.320811292335,38564.95363136622,29564.748240853,8859.623340059441,3095.403584733703,40880.967025209895,32768.970849750534,12125.16093537245,13712.773346544258,2428 ...

# %%
1/0.01932367
# Out:
# 51.75000401062531

# %%
# ADF test
from statsmodels.tsa.stattools import adfuller
result = adfuller(df_weekly['EC'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -4.302692
# p-value: 0.000439

# %%
# ACF plot
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(df_weekly["EC"],lags=20)
plt.show()

# %%
# PACF plot
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(df_weekly['EC'],lags=50)
plt.show()

# %%
# spliting
train = df_weekly[:int(0.95*(len(df_weekly)))]
test = df_weekly[int(0.95*(len(df_weekly))):]

# %%
train.shape
# Out:
# (196, 1)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
import warnings
warnings.filterwarnings("ignore")
l=[]
def models(p,q):
    model = ARIMA(train['EC'], order=(p,0,q))
    m=model.fit()
    l.append([[(p,0,q)],m.aic])

# %%
from itertools import product
p = range(0, 6)
q = range(0, 6)

# %%
for p,q in product(p,q):
   models(p,q)

# %%
d=pd.DataFrame(l,columns=["Model","AIC"])
data=d.sort_values(by="AIC",ascending=True)
data.head(5)
# Out:
#           Model          AIC
# 17  [(2, 0, 5)]  3580.623797
# 23  [(3, 0, 5)]  3585.589613
# 21  [(3, 0, 3)]  3600.296919
# 27  [(4, 0, 3)]  3601.521034
# 22  [(3, 0, 4)]  3601.931163

# %%
#fitting ARIMA(2,0,5)
model = ARIMA(train['EC'], order=(2,0,5))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                     EC   No. Observations:                  196
# Model:                 ARIMA(2, 0, 5)   Log Likelihood               -1781.312
# Date:                Sun, 09 Aug 2026   AIC                           3580.624
# Time:                        09:42:01   BIC                           3610.127
# Sample:                    12-17-2006   HQIC                          3592.568
#                          - 09-12-2010
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.082e+04    200.143     54.079      0.000    1.04e+04    1.12e+04
# ar.L1          1.9846      0.002   1206.043      0.000       1.981       1.988
# ar.L2         -0.9988      0.001   -676.657      0.000      -1.002      -0.996
# ma.L1         -1.6704      0.076    -22.110      0.000      -1.818      -1.522
# ma.L2          0.5553      0.115      4.833      0.000       0.330       0.780
# ma.L3          0.0668      0.155      0.430      0.667      -0.237       0.371
# ma.L4         -0.0646      0.175     -0.369      0.712      -0.408       0.279
# ma.L5          0.1288      0.088      1.467      0.142      -0.043       0.301
# sigma2      3.827e+06      0.001   5.89e+09      0.000    3.83e+06    3.83e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.16   Jarque-Bera (JB):               113.81
# Prob(Q):                              0.69   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.41   Skew:                            -0.29
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.76e+26. Standard errors may be unstable.

# %%
model_fit.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
# Predict on training data (in-sample fit)
train_preds = model_fit.fittedvalues

# Predict on test data (out-of-sample forecast)
test_preds = model_fit.forecast(steps=len(test))

# %%
import plotly.graph_objects as go

fig = go.Figure()

# Actual train
fig.add_trace(go.Scatter(x=train.index, y=train['EC'], mode='lines', name='Observed - Train'))

# Actual test
fig.add_trace(go.Scatter(x=test.index, y=test['EC'], mode='lines', name='Observed - Test'))

# Predicted train
fig.add_trace(go.Scatter(x=train.index, y=train_preds, mode='lines', name='Predicted - Train'))

# Predicted test
fig.add_trace(go.Scatter(x=test.index, y=test_preds, mode='lines', name='Predicted - Test'))

# Layout
fig.update_layout(
    title='Observed vs Predicted EC (Train & Test)',
    xaxis_title='Date',
    yaxis_title='EC'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ea34039-dfd5-4888-91fb-a1bbba832314" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ea34039-dfd5-4888-91fb-a1bbba832314")) {                    Plotly.newPlot(                        "0ea34039-dfd5-4888-91fb-a1bbba832314",                        [{"mode":"lines","name":"Observed - Train","x":["2006-12-17T00:00:00","2006-12-24T00:00:00","2006-12-31T00:00:00","2007-01-07T00:00:00","2007-01-14T00:00:00","2007-01-21T00:00:00","2007-01-28T00:00:00","2007-02-04T00:00:00","2007-02-11T00:00:00","2007-02-18T00:00:00","2007-02-25T00:00:00","2007-03-04T00:00:00","2007-03-11T00:00:00","2007-03-18T00:00:00","2007-03-25T00:00:00","2007-04-01T00:00:00","2007-04-08T00:00:00","2007-04-15T00:00:00","2007-04-22T00:00:00","2007-04-29T00:00:00","2007-05-06T00:00:00","2007-05-13T00:00:00","2007-05-20T00:00:00","2007-05-27T00:00:00","2007-06-03T00:00:00","2007-06-10T00:00:00","2007-06-17T00:00:00","2007-06-24T00:00:00","2007-07-01T00:00:00","2007-07-08T00:00:00","2007-07-15T00:00:00","2007-07-22T00:00:00","2007-07-29T00:00:00","2007-08-05T00:00:00","2007-08-12T00:00:00","2007-08-19T00:00:00","2007-08-26T00:00:00","2007-09-02T00:00:00","2007-09-09T00:00:00","2007-09-16T00:00:00","2007-09-23T00:00:00","2007-09-30T00:00:00","2007-10-07T00:00:00","2007-10-14T00:00:00","2007-10-21T00:00:00","2007-10-28T00:00:00","2007-11-04T00:00:00","2007-11-11T00:00:00","2007-11-18T00:00:00","2007-11-25T00:00:00","2007-12-02T00:00:00","2007-12-09T00:00:00","2007-12-16T00:00:00","2007-12-23T00:00:00","2007-12-30T00:00:00","2008-01-06T00:00:00","2008-01-13T00:00:00","2008-01-20T00:00:00","2008-01-27T00:00:00","2008-02-03T00:00:00","2008-02-10T00:00:00","2008-02-17T00:00:00","2008-02-24T00:00:00","2008-03-02T00:00:00","2008-03-09T00:00:00","2008-03-16T00:00:00","2008-03-23T00:00:00","2008-03-30T00:00:00","2008-04-06T00:00:00","2008-04-13T00:00:00","2008-04-20T00:00:00","2008-04-27T00:00:00","2008-05-04T00:00:00","2008-05-11T00:00:00","2008-05-18T00:00:00","2008-05-25T00:00:00","2008-06-01T00:00:00","2008-06-08T00:00:00","2008-06-15T00:00:00","2008-06-22T00:00:00","2008-06-29T00:00:00","2008-07-06T00:00:00","2008-07-13T00:00:00","2008-07-20T00:00:00","2008-07-27T00:00:00","2008-08-03T00:00:00","2008-08-10T00:00:00","2008-08-17T00:00:00","2008-08-24T00:00:00","2008-08-31T00:00:00","2008-09-07T00:00:00","2008-09-14T00:00:00","2008-09-21T00:00:00","2008-09-28T00:00:00","2008-10-05T00:00:00","2008-10-12T00:00:00","2008-10-19T00:00:00","2008-10-26T00:00:00","2008-11-02T00:00:00","2008-11-09T00:00:00","2008-11-16T00:00:00","2008-11-23T00:00:00","2008-11-30T00:00:00","2008-12-07T00:00:00","2008-12-14T00:00:00","2008-12-21T00:00:00","2008-12-28T00:00:00","2009-01-04T00:00:00","2009-01-11T00:00:00","2009-01-18T00:00:00","2009-01-25T00:00:00","2009-02-01T00:00:00","2009-02-08T00:00:00","2009-02-15T00:00:00","2009-02-22T00:00:00","2009-03-01T00:00:00","2009-03-08T00:00:00","2009-03-15T00:00:00","2009-03-22T00:00:00","2009-03-29T00:00:00","2009-04-05T00:00:00","2009-04-12T00:00:00","2009-04-19T00:00:00","2009-04-26T00:00:00","2009-05-03T00:00:00","2009-05-10T00:00:00","2009-05-17T00:00:00","2009-05-24T00:00:00","2009-05-31T00:00:00","2009-06-07T00:00:00","2009-06-14T00:00:00","2009-06-21T00:00:00","2009-06-28T00:00:00","2009-07-05T00:00:00","2009-07-12T00:00:00","2009-07-19T00:00:00","2009-07-26T00:00:00","2009-08-02T00:00:00","2009-08-09T00:00:00","2009-08-16T00:00:00","2009-08-23T00:00:00","2009-08-30T00:00:00","2009-09-06T00:00:00","2009-09-13T00:00:00","2009-09-20T00:00:00","2009-09-27T00:00:00","2009-10-04T00:00:00","2009-10-11T00:00:00","2009-10-18T00:00:00","2009-10-25T00:00:00","2009-11-01T00:00:00","2009-11-08T00:00:00","2009-11-15T00:00:00","2009-11-22T00:00:00"," ...

# %%
arima_mape = np.mean(np.abs(model_fit.predict(start=len(train),end=len(df_weekly)-1)-test['EC'])/np.abs(test['EC']))

# %%
arima_mape
# Out:
# np.float64(0.1781777528650964)

# %%
#Sarima model
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
l=[]
def models(p,q,P,Q):
    model=SARIMAX(train,order=(p,0,q),
                       seasonal_order=(P,0,Q,52))
    try:
        m=model.fit()
        l.append([[(p,0,q),(P,0,Q)],m.aic,np.mean(np.abs(m.predict(start=len(train),end=len(df_weekly)-1)-test['EC'])/np.abs(test['EC']))])
    except:
        print("Error in fitting model for parameters: ", (p,0,q), (P,0,Q))
        pass

# %%
from itertools import product
p = range(0, 3)
q = range(0, 3)
P = range(0, 2)
Q = range(0, 2)

# %%
for params in set(product(p,q,P,Q)):
   models(*params)

# %%
d=pd.DataFrame(l,columns=["Model","AIC","MAPE"])
data=d.sort_values(by="AIC",ascending=True)
data.head(10)
# Out:
#                      Model          AIC      MAPE
# 24  [(2, 0, 2), (1, 0, 0)]  3600.851061  0.154902
# 20  [(2, 0, 1), (1, 0, 0)]  3602.667495  0.169335
# 16  [(1, 0, 1), (1, 0, 1)]  3602.790993  0.162705
# 29  [(1, 0, 1), (1, 0, 0)]  3602.799110  0.164127
# 14  [(1, 0, 2), (1, 0, 0)]  3603.007252  0.165691
# 10  [(2, 0, 1), (1, 0, 1)]  3603.142120  0.165328
# 1   [(1, 0, 2), (1, 0, 1)]  3603.468050  0.164001
# 35  [(1, 0, 1), (0, 0, 1)]  3605.721377  0.174948
# 30  [(2, 0, 1), (0, 0, 1)]  3606.511345  0.189689
# 23  [(1, 0, 2), (0, 0, 1)]  3606.729665  0.182354

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
order = (2, 0, 2)                  # Non-seasonal (p, d, q)
seasonal_order = (1, 0, 0, 52)    # Seasonal (P, D, Q, s)

# Fit the model (enable checks for faster convergence)
model = SARIMAX(train["EC"],
                order=order,
                seasonal_order=seasonal_order
                )
results = model.fit(disp=False)

# %%
print(results.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                  EC   No. Observations:                  196
# Model:             SARIMAX(2, 0, 2)x(1, 0, [], 52)   Log Likelihood               -1794.426
# Date:                             Sun, 09 Aug 2026   AIC                           3600.851
# Time:                                     09:50:57   BIC                           3620.520
# Sample:                                 12-17-2006   HQIC                          3608.814
#                                       - 09-12-2010
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.8398      0.117     15.760      0.000       1.611       2.069
# ar.L2         -0.8400      0.116     -7.239      0.000      -1.067      -0.613
# ma.L1         -1.2821      0.133     -9.623      0.000      -1.543      -1.021
# ma.L2          0.3034      0.092      3.303      0.001       0.123       0.483
# ar.S.L52       0.3547      0.052      6.813      0.000       0.253       0.457
# sigma2      4.873e+06   1.36e-08   3.59e+14      0.000    4.87e+06    4.87e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               116.36
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.51   Skew:                             0.45
# Prob(H) (two-sided):                  0.01   Kurtosis:                         6.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.5e+30. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
# Predict on training data (in-sample fit)
train_preds = results.fittedvalues

# Predict on test data (out-of-sample forecast)
test_preds = results.forecast(steps=len(test))

# %%
import plotly.graph_objects as go

fig = go.Figure()

# Actual train
fig.add_trace(go.Scatter(x=train.index, y=train['EC'], mode='lines', name='Observed - Train'))

# Actual test
fig.add_trace(go.Scatter(x=test.index, y=test['EC'], mode='lines', name='Observed - Test'))

# Predicted train
fig.add_trace(go.Scatter(x=train.index, y=train_preds, mode='lines', name='Predicted - Train'))

# Predicted test
fig.add_trace(go.Scatter(x=test.index, y=test_preds, mode='lines', name='Predicted - Test'))

# Layout
fig.update_layout(
    title='Observed vs Predicted EC (Train & Test)',
    xaxis_title='Date',
    yaxis_title='EC'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5445d274-557a-4cea-ae9b-a1e1e4fdd9e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5445d274-557a-4cea-ae9b-a1e1e4fdd9e4")) {                    Plotly.newPlot(                        "5445d274-557a-4cea-ae9b-a1e1e4fdd9e4",                        [{"mode":"lines","name":"Observed - Train","x":["2006-12-17T00:00:00","2006-12-24T00:00:00","2006-12-31T00:00:00","2007-01-07T00:00:00","2007-01-14T00:00:00","2007-01-21T00:00:00","2007-01-28T00:00:00","2007-02-04T00:00:00","2007-02-11T00:00:00","2007-02-18T00:00:00","2007-02-25T00:00:00","2007-03-04T00:00:00","2007-03-11T00:00:00","2007-03-18T00:00:00","2007-03-25T00:00:00","2007-04-01T00:00:00","2007-04-08T00:00:00","2007-04-15T00:00:00","2007-04-22T00:00:00","2007-04-29T00:00:00","2007-05-06T00:00:00","2007-05-13T00:00:00","2007-05-20T00:00:00","2007-05-27T00:00:00","2007-06-03T00:00:00","2007-06-10T00:00:00","2007-06-17T00:00:00","2007-06-24T00:00:00","2007-07-01T00:00:00","2007-07-08T00:00:00","2007-07-15T00:00:00","2007-07-22T00:00:00","2007-07-29T00:00:00","2007-08-05T00:00:00","2007-08-12T00:00:00","2007-08-19T00:00:00","2007-08-26T00:00:00","2007-09-02T00:00:00","2007-09-09T00:00:00","2007-09-16T00:00:00","2007-09-23T00:00:00","2007-09-30T00:00:00","2007-10-07T00:00:00","2007-10-14T00:00:00","2007-10-21T00:00:00","2007-10-28T00:00:00","2007-11-04T00:00:00","2007-11-11T00:00:00","2007-11-18T00:00:00","2007-11-25T00:00:00","2007-12-02T00:00:00","2007-12-09T00:00:00","2007-12-16T00:00:00","2007-12-23T00:00:00","2007-12-30T00:00:00","2008-01-06T00:00:00","2008-01-13T00:00:00","2008-01-20T00:00:00","2008-01-27T00:00:00","2008-02-03T00:00:00","2008-02-10T00:00:00","2008-02-17T00:00:00","2008-02-24T00:00:00","2008-03-02T00:00:00","2008-03-09T00:00:00","2008-03-16T00:00:00","2008-03-23T00:00:00","2008-03-30T00:00:00","2008-04-06T00:00:00","2008-04-13T00:00:00","2008-04-20T00:00:00","2008-04-27T00:00:00","2008-05-04T00:00:00","2008-05-11T00:00:00","2008-05-18T00:00:00","2008-05-25T00:00:00","2008-06-01T00:00:00","2008-06-08T00:00:00","2008-06-15T00:00:00","2008-06-22T00:00:00","2008-06-29T00:00:00","2008-07-06T00:00:00","2008-07-13T00:00:00","2008-07-20T00:00:00","2008-07-27T00:00:00","2008-08-03T00:00:00","2008-08-10T00:00:00","2008-08-17T00:00:00","2008-08-24T00:00:00","2008-08-31T00:00:00","2008-09-07T00:00:00","2008-09-14T00:00:00","2008-09-21T00:00:00","2008-09-28T00:00:00","2008-10-05T00:00:00","2008-10-12T00:00:00","2008-10-19T00:00:00","2008-10-26T00:00:00","2008-11-02T00:00:00","2008-11-09T00:00:00","2008-11-16T00:00:00","2008-11-23T00:00:00","2008-11-30T00:00:00","2008-12-07T00:00:00","2008-12-14T00:00:00","2008-12-21T00:00:00","2008-12-28T00:00:00","2009-01-04T00:00:00","2009-01-11T00:00:00","2009-01-18T00:00:00","2009-01-25T00:00:00","2009-02-01T00:00:00","2009-02-08T00:00:00","2009-02-15T00:00:00","2009-02-22T00:00:00","2009-03-01T00:00:00","2009-03-08T00:00:00","2009-03-15T00:00:00","2009-03-22T00:00:00","2009-03-29T00:00:00","2009-04-05T00:00:00","2009-04-12T00:00:00","2009-04-19T00:00:00","2009-04-26T00:00:00","2009-05-03T00:00:00","2009-05-10T00:00:00","2009-05-17T00:00:00","2009-05-24T00:00:00","2009-05-31T00:00:00","2009-06-07T00:00:00","2009-06-14T00:00:00","2009-06-21T00:00:00","2009-06-28T00:00:00","2009-07-05T00:00:00","2009-07-12T00:00:00","2009-07-19T00:00:00","2009-07-26T00:00:00","2009-08-02T00:00:00","2009-08-09T00:00:00","2009-08-16T00:00:00","2009-08-23T00:00:00","2009-08-30T00:00:00","2009-09-06T00:00:00","2009-09-13T00:00:00","2009-09-20T00:00:00","2009-09-27T00:00:00","2009-10-04T00:00:00","2009-10-11T00:00:00","2009-10-18T00:00:00","2009-10-25T00:00:00","2009-11-01T00:00:00","2009-11-08T00:00:00","2009-11-15T00:00:00","2009-11-22T00:00:00"," ...

# %%
sarima_mape = np.mean(np.abs(results.predict(start=len(train),end=len(df_weekly)-1)-test['EC'])/np.abs(test['EC']))

# %%
sarima_mape
# Out:
# np.float64(0.1549017364966099)

# %%
models = ['ARIMA', 'SARIMA']
mape_values = [arima_mape, sarima_mape]
# Create bar plot
plt.figure(figsize=(5, 2))
bars = plt.bar(models, mape_values, color=['skyblue', 'orange'])

# Add value labels on top
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.3, f'{yval:.2f}%', ha='center', fontsize=10)

# Aesthetics
plt.title('MAPE Comparison of ARIMA and SARIMA Models')
plt.ylabel('MAPE (%)')
plt.ylim(0, max(mape_values) + 0.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
## fitting deep learning models
df_hourly = df1.resample('H').sum()

# %%
df_hourly.columns=["EC"]
df_hourly.shape
# Out:
# (34589, 1)

# %%
df_hourly.plot()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df_hourly[['EC']])

# %%
def create_sequences(data, time_steps=30):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps])
        y.append(data[i + time_steps])
    return np.array(X), np.array(y)

time_steps = 30
X, y = create_sequences(scaled_data, time_steps)

# %%
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.layers import Dropout
model_rnn = Sequential([
    SimpleRNN(64, activation='relu', return_sequences=False, input_shape=(time_steps, 1)),
    Dropout(0.2),
    Dense(32, activation='relu'),   # Added dense layer
    Dropout(0.2),
    Dense(16, activation='relu'),   # Another dense layer
    Dense(1)
])

model_rnn.compile(optimizer='adam', loss='mse')
model_rnn.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0109 - val_loss: 0.0066
# Epoch 2/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0098 - val_loss: 0.0067
# Epoch 3/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0096 - val_loss: 0.0063
# Epoch 4/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0094 - val_loss: 0.0063
# Epoch 5/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0091 - val_loss: 0.0062
# Epoch 6/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0090 - val_loss: 0.0061
# Epoch 7/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0089 - val_loss: 0.0061
# Epoch 8/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0088 - val_loss: 0.0063
# Epoch 9/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0088 - val_loss: 0.0060
# Epoch 10/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0087 - val_loss: 0.0061
# Epoch 11/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0087 - val_loss: 0.0060
# Epoch 12/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0087 - val_loss: 0.0060
# Epoch 13/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0087 - val_loss: 0.0060
# Epoch 14/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 0.0087 - val_loss: 0.0061
# Epoch 15/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.0086 - val_loss: 0.0060
# Epoch 16/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0086 - val_loss: 0.0059
# Epoch 17/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 0.0086 - val_loss: 0.0059
# Epoch 18/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0086 - val_loss: 0.0060
# Epoch 19/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0085 - val_loss: 0.0059
# Epoch 20/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0085 - val_loss: 0.0061

# %%
from tensorflow.keras.layers import LSTM

model_lstm = Sequential([
    LSTM(64, activation='relu', return_sequences=False, input_shape=(time_steps, 1)),
    Dropout(0.2),
    Dense(32, activation='relu'),   # Added dense layer
    Dropout(0.2),
    Dense(16, activation='relu'),   # Another dense layer

    Dense(1)
])

model_lstm.compile(optimizer='adam', loss='mse')
model_lstm.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 0.0127 - val_loss: 0.0069
# Epoch 2/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 24s 25ms/step - loss: 0.0103 - val_loss: 0.0068
# Epoch 3/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - loss: 0.0101 - val_loss: 0.0065
# Epoch 4/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 0.0098 - val_loss: 0.0075
# Epoch 5/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 0.0098 - val_loss: 0.0065
# Epoch 6/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 0.0096 - val_loss: 0.0064
# Epoch 7/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 0.0095 - val_loss: 0.0064
# Epoch 8/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - loss: 0.0095 - val_loss: 0.0064
# Epoch 9/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 22s 19ms/step - loss: 0.0093 - val_loss: 0.0064
# Epoch 10/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - loss: 0.0092 - val_loss: 0.0065
# Epoch 11/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 0.0091 - val_loss: 0.0061
# Epoch 12/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 0.0091 - val_loss: 0.0061
# Epoch 13/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 0.0089 - val_loss: 0.0061
# Epoch 14/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 0.0088 - val_loss: 0.0062
# Epoch 15/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - loss: 0.0089 - val_loss: 0.0061
# Epoch 16/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - loss: 0.0088 - val_loss: 0.0060
# Epoch 17/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 0.0088 - val_loss: 0.0060
# Epoch 18/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 0.0087 - val_loss: 0.0061
# Epoch 19/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - loss: 0.0087 - val_loss: 0.0059
# Epoch 20/20
# 864/864 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 0.0087 - val_loss: 0.0059

# %%
pred_lstm = model_lstm.predict(X_test)
pred_rnn = model_rnn.predict(X_test)

# Inverse transform to original scale
y_test_inv = scaler.inverse_transform(y_test)
pred_lstm_inv = scaler.inverse_transform(pred_lstm)
pred_rnn_inv = scaler.inverse_transform(pred_rnn)

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test_inv, label='Actual')
plt.plot(pred_lstm_inv, label='LSTM Predicted')
plt.plot(pred_rnn_inv, label='RNN Predicted')
plt.legend()
plt.title('Actual vs Predicted Electricity Consumption')
plt.show()

# %%
def mape(y_true, y_pred):
    epsilon = 1e-1
    return np.mean(np.abs((y_true - y_pred) / (y_true + epsilon)))

print("LSTM MAPE:", mape(y_test_inv, pred_lstm_inv))
print("RNN MAPE:", mape(y_test_inv, pred_rnn_inv))

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from tensorflow.keras.layers import Bidirectional, LSTM, Dense
from tensorflow.keras.models import Sequential

model_bilstm = Sequential([
    Bidirectional(LSTM(128, activation='relu'), input_shape=(time_steps, 1)),
    Dense(64, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1)  # Output layer for regression
])

model_bilstm.compile(optimizer='adam', loss='mse')
model_bilstm.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# %%
pred_bilstm = model_bilstm.predict(X_test)
y_test_inv = scaler.inverse_transform(y_test)
pred_bilstm_inv = scaler.inverse_transform(pred_bilstm)
print("BiLSTM MAPE:", mape(y_test_inv, pred_bilstm_inv))

# %%
# Assuming predictions are already made
pred_rnn = model_rnn.predict(X_test)
pred_lstm = model_lstm.predict(X_test)
pred_bilstm = model_bilstm.predict(X_test)

# Inverse transform all predictions and y_test
pred_rnn_inv = scaler.inverse_transform(pred_rnn)
pred_lstm_inv = scaler.inverse_transform(pred_lstm)
pred_bilstm_inv = scaler.inverse_transform(pred_bilstm)
y_test_inv = scaler.inverse_transform(y_test)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

# Plot actual values
plt.plot(y_test_inv, label='Actual', color='blue')

# Plot predictions
plt.plot(pred_rnn_inv, label='RNN', color='green', alpha=0.7)
plt.plot(pred_lstm_inv, label='LSTM', color='orange', alpha=0.7)
plt.plot(pred_bilstm_inv, label='BiLSTM', color='red', alpha=0.7)

plt.title('Electricity Consumption: Actual vs RNN, LSTM, BiLSTM')
plt.xlabel('Time')
plt.ylabel('Electricity Consumption')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def mape(y_true, y_pred):
    epsilon = 1e-10  # small constant to avoid division by zero
    return np.mean(np.abs((y_true - y_pred) / (y_true + epsilon))) * 100

# Compute MAPE scores
mape_rnn = mape(y_test_inv, pred_rnn_inv)
mape_lstm = mape(y_test_inv, pred_lstm_inv)
mape_bilstm = mape(y_test_inv, pred_bilstm_inv)

# %%
import matplotlib.pyplot as plt

# Model names and scores
models = ['RNN', 'LSTM', 'BiLSTM']
mape_scores = [mape_rnn, mape_lstm, mape_bilstm]

# Plot
plt.figure(figsize=(6,5))
bars = plt.bar(models, mape_scores, color=['green', 'orange', 'red'])

# Annotate bars with MAPE values
for bar in bars:
    height = bar.get_height()
    #plt.text(bar.get_x() + bar.get_width()/2, height + 0.5, f"{height:.2f}", ha='center', va='bottom')

plt.title('MAPE Comparison of Models')
plt.ylabel('MAPE')
plt.ylim(0, max(mape_scores)*1.2)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you trained the model as: history = model.fit(...)
history_bilstm = model_bilstm.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
plt.figure(figsize=(8,5))
plt.plot(history_bilstm.history['loss'], label='Training Loss')
plt.plot(history_bilstm.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming y_test and y_pred are numpy arrays
residuals = y_test_inv - pred_bilstm_inv

plt.figure(figsize=(10,4))
plt.plot(residuals)
plt.title("Residuals Over Time")
plt.xlabel("Time")
plt.ylabel("Residual")
plt.show()

# Histogram of residuals
sns.histplot(residuals, kde=True, bins=30)
plt.title("Distribution of Residuals")
plt.show()
